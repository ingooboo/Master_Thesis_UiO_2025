# %% [markdown]
# # STEP 0 : TASK 1 : FILTERING - LEVEL 2 VS. LEVEL 3
#
# ### Ingvild Olden Bjerkelund

# %% [markdown]
# ### Import all packages

# %%
# import python packages
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy as cy
from matplotlib.dates import DateFormatter
import cartopy.crs as ccrs 
import cmocean
import netCDF4 as nc
import glob as glob
import pandas as pd
# SOFI
#import SWOT_Oceanography_Functions_Ingvild as sofi
import SWOT_PLOT_Step_2_Func as plt_s2
import SWOT_Step_2_make_files as step_2
import SOFiA as SOFiA
from numpy import linalg as LA
# Binning (Jonathan)
from scipy.stats import binned_statistic_2d
import cartopy.feature as cfeature
import cmcrameri as cmc

from scipy.ndimage import gaussian_filter, gaussian_laplace, fourier_gaussian

# %% [markdown]
# ## LEVEL 2 :

# %%
pass_003_file = '/uio/hypatia/geofag-personlig/students/metos/ingvilob/SWOT_1_RAW_MERGED/version_2/pass_003.nc'
pass_003 = xr.open_dataset(pass_003_file)
#pass_003['concat_dim'][23]

# %%
#pass_003_file = '/uio/hypatia/geofag-personlig/students/metos/ingvilob/A_SSHA_CORR_NETCDF/pass_003.nc'
#pass_003 = xr.open_dataset(pass_003_file)

# %%
pass_003_cyc_25 = pass_003.isel(concat_dim=23)
pass_003_cyc_25

# %%
ssha_k2_l2_s0, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin_2', 'ssha', 'all', None)
ssha_k1_l2_s0, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin',   'ssha', 'all', None)
ssha_k2_l2_s1, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin_2', 'ssha', 'all', 1)
ssha_k1_l2_s1, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin',   'ssha', 'all', 1)
ssha_k2_l2_s2, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin_2', 'ssha', 'all', 2)
ssha_k1_l2_s2, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin',   'ssha', 'all', 2)
ssha_k2_l2_s3, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin_2', 'ssha', 'all', 3)
ssha_k1_l2_s3, lat, lon, _, _, _, _, _ = SOFiA.get_corrected_and_masked_variables2(pass_003, 'ssha_karin',   'ssha', 'all', 3)

# %%
ssha_k2_l2_s0_cyc25 = ssha_k2_l2_s0[23]
ssha_k1_l2_s0_cyc25 = ssha_k1_l2_s0[23]
ssha_k2_l2_s1_cyc25 = ssha_k2_l2_s1[23]
ssha_k1_l2_s1_cyc25 = ssha_k1_l2_s1[23]
ssha_k2_l2_s2_cyc25 = ssha_k2_l2_s2[23]
ssha_k1_l2_s2_cyc25 = ssha_k1_l2_s2[23]
ssha_k2_l2_s3_cyc25 = ssha_k2_l2_s3[23]
ssha_k1_l2_s3_cyc25 = ssha_k1_l2_s3[23]

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(11, 15))

a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k1_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k1_l2_s0_cyc25-ssha_k2_l2_s0_cyc25, cmap=cmocean.cm.balance, vmin=-0.04, vmax=0.04)

ax1.set_title("ssha_karin_2", fontsize=15)
ax1.set_ylim(300,800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("ssha_karin", fontsize=15)
ax2.set_ylim(300,800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("ssha_karin-ssha_karin_2", fontsize=15)
ax3.set_ylim(300,800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN SMOOTHED
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(15, 15))

a = ax1.imshow(ssha_k1_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k1_l2_s1_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k1_l2_s2_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
d = ax4.imshow(ssha_k1_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)

ax1.set_title("Smoothed 0 times", fontsize=15)
ax1.set_ylim(300,800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Smoothed 1 times", fontsize=15)
ax2.set_ylim(300,800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Smoothed 2 times", fontsize=15)
ax3.set_ylim(300,800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Smoothed 3 times", fontsize=15)
ax4.set_ylim(300,800)
cbard = plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN_2 SMOOTHED
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(15, 15))

a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k2_l2_s1_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k2_l2_s2_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)

ax1.set_title("Smoothed 0 times", fontsize=15)
ax1.set_ylim(300,800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Smoothed 1 times", fontsize=15)
ax2.set_ylim(300,800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Smoothed 2 times", fontsize=15)
ax3.set_ylim(300,800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Smoothed 3 times", fontsize=15)
ax4.set_ylim(300,800)
cbard = plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 10))

a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k2_l2_s1_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s2_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

ax1.set_title("Unsmoothed", fontsize=15)
ax1.set_ylim(550,750)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Smoothed 2 times", fontsize=15)
ax2.set_ylim(550,750)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Unsmoothed-Smoothed 2 times", fontsize=15)
ax3.set_ylim(550,750)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 10))

a = ax1.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s1_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
b = ax2.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s2_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
c = ax3.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

ax1.set_title("Unsmoothed-Smoothed 1 time", fontsize=15)
ax1.set_ylim(300,500)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Unsmoothed-Smoothed 2 time", fontsize=15)
ax2.set_ylim(300,500)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Unsmoothed-Smoothed 3 time", fontsize=15)
ax3.set_ylim(300,500)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 10))#, subplot_kw=dict(projection=ccrs.PlateCarree()))
#ax1.set_extent([-50, -40, 39, 56])
#ax2.set_extent(localbox)
#ax3.set_extent(localbox)
plot_kwargs = dict(
    x="longitude",
    y="latitude",
    cmap="Spectral_r",
    vmin=-0.2,
    vmax=0.2,
    cbar_kwargs={"shrink": 0.3},)

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k2_l2_s1_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k1_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
d = ax4.imshow(ssha_k1_l2_s1_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)

#
ax1.set_title("ssha_karin_2")
ax1.set_ylim(300,700)
plt.colorbar(a)
ax2.set_title("ssha_karin_2")
ax2.set_ylim(300,700)
plt.colorbar(b)
ax3.set_title("ssha_karin")
ax3.set_ylim(300,700)
plt.colorbar(c)
ax4.set_title("ssha_karin")
ax4.set_ylim(300,700)
plt.colorbar(d)

# %% [markdown]
# ## LEVEL 3 :

# %%
pass_003_cycle_25_level_3_file = '/uio/hypatia/geofag-personlig/students/metos/ingvilob/test_l3/l3_expert_pass_003_cycle_25.nc'
pass_003_cycle_25_level_3 = xr.open_dataset(pass_003_cycle_25_level_3_file)
pass_003_cycle_25_level_3

# %%
# set figure
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, figsize=(22, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(pass_003_cyc_25.mean_sea_surface_cnescls, cmap='Spectral_r', vmin=0, vmax=60)
b = ax2.imshow(pass_003_cycle_25_level_3.mss, cmap='Spectral_r', vmin=0, vmax=60)
c = ax3.imshow(pass_003_cyc_25.mean_sea_surface_cnescls-pass_003_cycle_25_level_3.mss, cmap=cmocean.cm.balance, vmin=-0.01, vmax=0.01)

level_2_tides_ssha = pass_003_cyc_25['solid_earth_tide'] + pass_003_cyc_25['ocean_tide_fes'] + pass_003_cyc_25['ocean_tide_non_eq'] + pass_003_cyc_25['internal_tide_hret'] + pass_003_cyc_25['pole_tide']# - merged_dataset['dac']

d = ax4.imshow(level_2_tides_ssha, cmap='Spectral_r')#, vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ocean_tide+pass_003_cycle_25_level_3.internal_tide, cmap='Spectral_r')#, vmin=-0.1, vmax=0.2)
f = ax6.imshow(level_2_tides_ssha-(pass_003_cycle_25_level_3.ocean_tide+pass_003_cycle_25_level_3.internal_tide), cmap=cmocean.cm.balance, vmin=-0.5, vmax=0.5)

#
ax1.set_title("Level 2 - Unsmoothed")
#ax1.set_ylim(1400,1800)
cbara=plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 2 - Smoothed 3 times")
#ax2.set_ylim(1400,1800)
cbarb=plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Difference")
#ax3.set_ylim(1400,1800)
cbarc=plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 3 - Unfiltered")
#ax4.set_ylim(1400,1800)
cbard=plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 - Filtered")
#ax5.set_ylim(1400,1800)
cbare=plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)
ax6.set_title("Level 3 - Difference")
#ax6.set_ylim(1400,1800)
cbarf=plt.colorbar(f, aspect=40)
cbarf.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, figsize=(22, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(pass_003_cyc_25.height_cor_xover, cmap='Spectral_r', vmin=-1, vmax=1.5)
b = ax2.imshow(pass_003_cycle_25_level_3.calibration, cmap='Spectral_r', vmin=-1, vmax=1.5)
c = ax3.imshow(pass_003_cyc_25.height_cor_xover-pass_003_cycle_25_level_3.calibration, cmap=cmocean.cm.balance, vmin=-0.1, vmax=0.1)

d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
f = ax6.imshow(ssha_k2_l2_s3_cyc25-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

#
ax1.set_title("Level 2 - Unsmoothed")
#ax1.set_ylim(1400,1800)
cbara=plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 2 - Smoothed 3 times")
#ax2.set_ylim(1400,1800)
cbarb=plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Difference")
#ax3.set_ylim(1400,1800)
cbarc=plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 3 - Unfiltered")
#ax4.set_ylim(1400,1800)
cbard=plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 - Filtered")
#ax5.set_ylim(1400,1800)
cbare=plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)
ax6.set_title("Level 3 - Difference")
#ax6.set_ylim(1400,1800)
cbarf=plt.colorbar(f, aspect=40)
cbarf.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(11, 15))

a = ax1.imshow(pass_003_cycle_25_level_3.ssha_unedited, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered,   cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(pass_003_cycle_25_level_3.ssha_filtered,   cmap='Spectral_r', vmin=-0.1, vmax=0.2)

ax1.set_title("ssha_unedited", fontsize=15)
ax1.set_ylim(300,800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("ssha_unfiltered", fontsize=15)
ax2.set_ylim(300,800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("ssha_filtered", fontsize=15)
ax3.set_ylim(300,800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(11, 15))

a = ax1.imshow(pass_003_cycle_25_level_3.ssha_unfiltered,   cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_filtered,   cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

ax1.set_title("ssha_unfiltered", fontsize=15)
ax1.set_ylim(300,800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("ssha_filtered", fontsize=15)
ax2.set_ylim(300,800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("ssha_unfiltered-ssha_filtered", fontsize=15)
ax3.set_ylim(300,800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(10, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k2_l2_s2_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(pass_003_cycle_25_level_3.ssha_unfiltered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
d = ax4.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)

#
ax1.set_title("ssha_karin_2")
#ax1.set_ylim(300,700)
plt.colorbar(a)
ax2.set_title("ssha_karin_2")
#ax2.set_ylim(300,700)
plt.colorbar(b)
ax3.set_title("ssha_karin")
#ax3.set_ylim(300,700)
plt.colorbar(c)
ax4.set_title("ssha_karin")
#ax4.set_ylim(300,700)
plt.colorbar(d)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(15, 15))

a = ax1.imshow(ssha_k1_l2_s0_cyc25-ssha_k1_l2_s3_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
c = ax3.imshow(np.abs(ssha_k1_l2_s0_cyc25-ssha_k1_l2_s3_cyc25)-np.abs(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered), cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)


ax1.set_title("Level 2 - Difference", fontsize=15)
ax1.set_ylim(1000,1900)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 3 - Difference", fontsize=15)
ax2.set_ylim(1000,1900)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Level 3", fontsize=15)
ax3.set_ylim(1000,1900)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 2 smoothed 3 times", fontsize=15)
ax4.set_ylim(1000,1900)
cbard = plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 filtered", fontsize=15)
ax5.set_ylim(1000,1900)
cbare = plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(15, 15))

a = ax1.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
c = ax3.imshow(np.abs(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25)-np.abs(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered), cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)


ax1.set_title("Level 2 - Difference", fontsize=15)
#ax1.set_ylim(1400,1800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 3 - Difference", fontsize=15)
#ax2.set_ylim(1400,1800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Level 3", fontsize=15)
#ax3.set_ylim(1400,1800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 2 - Level 3", fontsize=15)
#ax4.set_ylim(1400,1800)
cbard = plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 2 - Level 3", fontsize=15)
#ax5.set_ylim(1400,1800)
cbare = plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 15))

a = ax1.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
c = ax3.imshow(np.abs(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25)-np.abs(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered), cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

ax1.set_title("Level 2 - Difference", fontsize=15)
ax1.set_ylim(1400,1800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 3 - Difference", fontsize=15)
ax2.set_ylim(1400,1800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Level 3", fontsize=15)
ax3.set_ylim(1400,1800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)

# %%
# PLOT SSHA_KARIN VS. SSHA_KARIN_2
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(11, 15))

a = ax1.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)
c = ax3.imshow((ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25)-(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered), cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

ax1.set_title("ssha_unfiltered", fontsize=15)
ax1.set_ylim(300,800)
cbara = plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("ssha_filtered", fontsize=15)
ax2.set_ylim(300,800)
cbarb = plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("ssha_unfiltered-ssha_filtered", fontsize=15)
ax3.set_ylim(300,800)
cbarc = plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, figsize=(22, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k2_l2_s0_cyc25-pass_003_cycle_25_level_3.ssha_unfiltered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
f = ax6.imshow(ssha_k2_l2_s3_cyc25-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

#
ax1.set_title("Level 2 - Unsmoothed")
#ax1.set_ylim(1400,1800)
cbara=plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 2 - Smoothed 3 times")
#ax2.set_ylim(1400,1800)
cbarb=plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Difference")
#ax3.set_ylim(1400,1800)
cbarc=plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 3 - Unfiltered")
#ax4.set_ylim(1400,1800)
cbard=plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 - Filtered")
#ax5.set_ylim(1400,1800)
cbare=plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)
ax6.set_title("Level 3 - Difference")
#ax6.set_ylim(1400,1800)
cbarf=plt.colorbar(f, aspect=40)
cbarf.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, figsize=(22, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k2_l2_s0_cyc25-pass_003_cycle_25_level_3.ssha_unfiltered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
f = ax6.imshow(ssha_k2_l2_s3_cyc25-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

#
ax1.set_title("Level 2 - Unsmoothed")
ax1.set_ylim(1400,1800)
cbara=plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 3 - Unfiltered")
ax2.set_ylim(1400,1800)
cbarb=plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Difference - Unfiltered")
ax3.set_ylim(1400,1800)
cbarc=plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 2 - Smoothed (3)")
ax4.set_ylim(1400,1800)
cbard=plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 - Filtered")
ax5.set_ylim(1400,1800)
cbare=plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)
ax6.set_title("Difference - Filtered")
ax6.set_ylim(1400,1800)
cbarf=plt.colorbar(f, aspect=40)
cbarf.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, figsize=(22, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k2_l2_s0_cyc25-pass_003_cycle_25_level_3.ssha_unfiltered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
f = ax6.imshow(ssha_k2_l2_s3_cyc25-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

#
ax1.set_title("Level 2 - Unsmoothed")
ax1.set_ylim(1400,1800)
cbara=plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 3 - Unfiltered")
ax2.set_ylim(1400,1800)
cbarb=plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Difference - Unfiltered")
ax3.set_ylim(1400,1800)
cbarc=plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 2 - Smoothed (3)")
ax4.set_ylim(1400,1800)
cbard=plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 - Filtered")
ax5.set_ylim(1400,1800)
cbare=plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)
ax6.set_title("Difference - Filtered")
ax6.set_ylim(1400,1800)
cbarf=plt.colorbar(f, aspect=40)
cbarf.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, figsize=(22, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(pass_003_cycle_25_level_3.ssha_unfiltered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k2_l2_s0_cyc25-pass_003_cycle_25_level_3.ssha_unfiltered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

d = ax4.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
f = ax6.imshow(ssha_k2_l2_s3_cyc25-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

#
ax1.set_title("Level 2 - Unsmoothed")
ax1.set_ylim(1400,1800)
cbara=plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 2 - Smoothed 3 times")
ax2.set_ylim(1400,1800)
cbarb=plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Difference")
ax3.set_ylim(1400,1800)
cbarc=plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 3 - Unfiltered")
ax4.set_ylim(1400,1800)
cbard=plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 - Filtered")
ax5.set_ylim(1400,1800)
cbare=plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)
ax6.set_title("Level 3 - Difference")
ax6.set_ylim(1400,1800)
cbarf=plt.colorbar(f, aspect=40)
cbarf.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6, figsize=(22, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k2_l2_s3_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(ssha_k2_l2_s0_cyc25-ssha_k2_l2_s3_cyc25, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

d = ax4.imshow(pass_003_cycle_25_level_3.ssha_unfiltered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
e = ax5.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
f = ax6.imshow(pass_003_cycle_25_level_3.ssha_unfiltered-pass_003_cycle_25_level_3.ssha_filtered, cmap=cmocean.cm.balance, vmin=-0.02, vmax=0.02)

#
ax1.set_title("Level 2 - Unsmoothed")
ax1.set_ylim(1400,1800)
cbara=plt.colorbar(a, aspect=40)
cbara.set_label('meter', fontsize=12)
ax2.set_title("Level 2 - Smoothed 3 times")
ax2.set_ylim(1400,1800)
cbarb=plt.colorbar(b, aspect=40)
cbarb.set_label('meter', fontsize=12)
ax3.set_title("Level 2 - Difference")
ax3.set_ylim(1400,1800)
cbarc=plt.colorbar(c, aspect=40)
cbarc.set_label('meter', fontsize=12)
ax4.set_title("Level 3 - Unfiltered")
ax4.set_ylim(1400,1800)
cbard=plt.colorbar(d, aspect=40)
cbard.set_label('meter', fontsize=12)
ax5.set_title("Level 3 - Filtered")
ax5.set_ylim(1400,1800)
cbare=plt.colorbar(e, aspect=40)
cbare.set_label('meter', fontsize=12)
ax6.set_title("Level 3 - Difference")
ax6.set_ylim(1400,1800)
cbarf=plt.colorbar(f, aspect=40)
cbarf.set_label('meter', fontsize=12)

# %%
# set figure
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20, 10))

# SWOT KaRIn SLA plots
a = ax1.imshow(ssha_k2_l2_s0_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
b = ax2.imshow(ssha_k2_l2_s2_cyc25, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
c = ax3.imshow(pass_003_cycle_25_level_3.ssha_unfiltered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)
d = ax4.imshow(pass_003_cycle_25_level_3.ssha_filtered, cmap='Spectral_r', vmin=-0.1, vmax=0.2)

#
ax1.set_title("ssha_karin_2")
ax1.set_ylim(300,700)
plt.colorbar(a)
ax2.set_title("ssha_karin_2")
ax2.set_ylim(300,700)
plt.colorbar(b)
ax3.set_title("ssha_karin")
ax3.set_ylim(300,700)
plt.colorbar(c)
ax4.set_title("ssha_karin")
ax4.set_ylim(300,700)
plt.colorbar(d)
